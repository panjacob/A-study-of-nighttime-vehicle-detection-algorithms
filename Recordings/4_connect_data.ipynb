_max': '0.34615384615384615'}, '0_10925': {'ground_truth': True, 'min_max': '0.3846153846153846'}, '0_10950': {'ground_truth': True, 'min_max': '0.21794871794871792'}, '0_10975': {'ground_truth': True, 'min_max': '0.23076923076923075'}, '0_11000': {'ground_truth': True, 'min_max': '0.24358974358974358'}, '0_11025': {'ground_truth': True, 'min_max': '0.2564102564102564'}, '0_11050': {'ground_truth': True, 'min_max': '0.2948717948717948'}, '0_11075': {'ground_truth': True, 'min_max': '0.3205128205128205'}, '0_11100': {'ground_truth': True, 'min_max': '0.3589743589743589'}, '0_11125': {'ground_truth': True, 'min_max': '0.4230769230769231'}, '0_11150': {'ground_truth': True, 'min_max': '0.6153846153846153'}, '0_11175': {'ground_truth': True, 'min_max': '0.48717948717948717'}, '0_11200': {'ground_truth': True, 'min_max': '0.5128205128205128'}, '0_11225': {'ground_truth': True, 'min_max': '0.5512820512820512'}, '0_11250': {'ground_truth': True, 'min_max': '0.41025641025641024'}, '0_11275': {'ground_truth': True, 'min_max': '0.3205128205128205'}, '0_11300': {'ground_truth': True, 'min_max': '0.2692307692307692'}, '0_11325': {'ground_truth': True, 'min_max': '0.3333333333333333'}, '0_11350': {'ground_truth': True, 'min_max': '0.2948717948717948'}, '0_11375': {'ground_truth': True, 'min_max': '0.2948717948717948'}, '0_11400': {'ground_truth': True, 'min_max': '0.3205128205128205'}, '0_11425': {'ground_truth': True, 'min_max': '0.20512820512820512'}, '0_11800': {'ground_truth': True}, '0_11825': {'ground_truth': True}, '0_11850': {'ground_truth': True}, '0_11875': {'ground_truth': True}, '0_11900': {'ground_truth': True}, '0_11925': {'ground_truth': True}, '0_11950': {'ground_truth': True}, '0_11975': {'ground_truth': True}, '0_12000': {'ground_truth': True}, '0_12025': {'ground_truth': True}, '0_12050': {'ground_truth': True}, '0_12075': {'ground_truth': True}, '0_12875': {'ground_truth': True, 'min_max': '0.20512820512820512'}, '0_12925': {'ground_truth': True, 'min_max': '0.1923076923076923'}, '0_12950': {'ground_truth': True, 'min_max': '0.20512820512820512'}, '0_12975': {'ground_truth': True, 'min_max': '0.20512820512820512'}, '0_13000': {'ground_truth': True, 'min_max': '0.20512820512820512'}, '0_13025': {'ground_truth': True, 'min_max': '0.20512820512820512'}, '0_13050': {'ground_truth': True, 'min_max': '0.20512820512820512'}, '0_13075': {'ground_truth': True, 'min_max': '0.20512820512820512'}, '0_13100': {'ground_truth': True, 'min_max': '0.20512820512820512'}, '0_13125': {'ground_truth': True, 'min_max': '0.21794871794871792'}, '0_13150': {'g ...

# %% [markdown]
# ## 1.2 Dane z czujnika z normalizacją min-max

# %%
with open('z_score.csv', newline='') as f:
    reader = csv.reader(f)
    your_list = list(reader)
    for id_, value in your_list:
        if id_ in data:
            data[id_]['z_score'] = value

# %% [markdown]
# ## 1.3 Wyniki inferencji

# %%
with open('inference.csv', newline='') as f:
    reader = csv.reader(f)
    your_list = list(reader)
    for id_, value in your_list:
        if id_ in data:
            data[id_]['predicted'] = value

# %% [markdown]
# # 2. Sortowanie danych

# %% [markdown]
# ## 2.1 Utworzenie listy, pominiędzie ramek niezawierajacych wszystkich informacji

# %%
data_list = []
for id_, x in data.items():
    if 'z_score' in x and 'min_max' in x and 'predicted' in x and 'ground_truth' in x:
        id_split = id_.split('_')
        video_id = int(id_split[0])
        frame_id = int(id_split[1])
        data_list.append((id_, video_id, frame_id,  float(x['z_score']), float(x['min_max']), x['predicted'] == "True", x['ground_truth']))

print(len(data_list))
# Out:
# 33362

# %%
import functools


def extract_ids(val):
    key = val[0]
    key_split = key.split('_')
    video_id = int(key_split[0])
    frame_id = int(key_split[1])
    return video_id, frame_id


def compare_id(x, y):
    v_x, f_x = extract_ids(x)
    v_y, f_y = extract_ids(y)
    v_x *= 1000_000
    v_y *= 1000_000
    return (v_x + f_x) - (v_y - f_y)
    # if v_x != v_y:
    #     return v_x > v_y
    # else:
    #     return f_x >= f_y


data_sorted = sorted(data_list, key=lambda key: (key[1], key[2]))
print(data_sorted[:100])
# Out:
# [('0_3002', 0, 3002, -0.014674097712154196, 0.20512820512820512, False, False), ('0_3003', 0, 3003, -0.1058639549288685, 0.1923076923076923, False, False), ('0_3006', 0, 3006, -0.1058639549288685, 0.1923076923076923, False, False), ('0_3007', 0, 3007, -0.1058639549288685, 0.1923076923076923, False, False), ('0_3009', 0, 3009, -0.014674097712154196, 0.20512820512820512, False, False), ('0_3010', 0, 3010, -0.014674097712154196, 0.20512820512820512, False, False), ('0_3013', 0, 3013, -0.014674097712154196, 0.20512820512820512, False, False), ('0_3014', 0, 3014, -0.014674097712154196, 0.20512820512820512, False, False), ('0_3016', 0, 3016, -0.014674097712154196, 0.20512820512820512, False, False), ('0_3017', 0, 3017, -0.014674097712154196, 0.20512820512820512, False, False), ('0_3020', 0, 3020, -0.014674097712154196, 0.20512820512820512, False, False), ('0_3021', 0, 3021, -0.014674097712154196, 0.20512820512820512, False, False), ('0_3024', 0, 3024, -0.014674097712154196, 0.20512820512820512, False, False), ('0_3027', 0, 3027, -0.014674097712154196, 0.20512820512820512, False, False), ('0_3028', 0, 3028, -0.014674097712154196, 0.20512820512820512, False, False), ('0_3031', 0, 3031, 0.07651575950455987, 0.21794871794871792, False, False), ('0_3032', 0, 3032, 0.07651575950455987, 0.21794871794871792, False, False), ('0_3034', 0, 3034, 0.07651575950455987, 0.21794871794871792, False, False), ('0_3035', 0, 3035, 0.07651575950455987, 0.21794871794871792, False, False), ('0_3038', 0, 3038, -0.014674097712154196, 0.20512820512820512, False, False), ('0_3039', 0, 3039, -0.014674097712154196, 0.20512820512820512, False, False), ('0_3041', 0, 3041, -0.014674097712154196, 0.20512820512820512, False, False), ('0_3042', 0, 3042, -0.014674097712154196, 0.20512820512820512, False, False), ('0_3045', 0, 3045, 0.07651575950455987, 0.21794871794871792, False, False), ('0_3046', 0, 3046, -0.014674097712154196, 0.20512820512820512, False, False), ('0_3049', 0, 3049, -0.014674097712154196, 0.20512820512820512, False, False), ('0_3052', 0, 3052, -0.014674097712154196, 0.20512820512820512, False, False), ('0_3053', 0, 3053, 0.07651575950455987, 0.21794871794871792, False, False), ('0_3056', 0, 3056, -0.014674097712154196, 0.20512820512820512, False, False), ('0_3057', 0, 3057, -0.014674097712154196, 0.20512820512820512, False, False), ('0_3059', 0, 3059, -0.014674097712154196, 0.20512820512820512, False, False), ('0_3060', 0, 3060, -0.014674097712154196, 0.20512820512820512, False, False), ('0_3063', 0, 3063, -0.014674097712154196, 0.20512820512820512, False, False), ('0_3064', 0, 3064, -0.014674097712154196, 0.20512820512820512, False, False), ('0_3066', 0, 3066, 0.07651575950455987, 0.21794871794871792, False, False), ('0_3067', 0, 3067, 0.07651575950455987, 0.21794871794871792, False, False), ('0_3070', 0, 3070, -0.014674097712154196, 0.20512820512820512, False, False), ('0_3071', 0, 3071, -0.014674097712154196, 0.20512820512820512, False, False), ('0_3074', 0, 3074, -0.014674097712154196, 0.20512820512820512, False, False), ('0_3077', 0, 3077, 0.07651575950455987, 0.21794871794871792, True, False), ('0_3078', 0, 3078, 0.07651575950455987, 0.21794871794871792, True, False), ('0_3081', 0, 3081, -0.014674097712154196, 0.20512820512820512, True, False), ('0_3082', 0, 3082, -0.014674097712154196, 0.20512820512820512, True, False), ('0_3084', 0, 3084, -0.014674097712154196, 0.20512820512820512, False, False), ('0_3085', 0, 3085, -0.014674097712154196, 0.20512820512820512, False, False), ('0_3088', 0, 3088, -0.014674097712154196, 0.20512820512820512, False, False), ('0_3089', 0, 3089, -0.014674097712154196, 0.20512820512820512, False, False), ('0_3091', 0, 3091, -0.014674097712154196, 0.20512820512820512, False, False), ('0_3092', 0, 3092, -0.014674097712154196, 0.20512820512820512, False, False), ('0_3095', 0, 3095, -0.014674097712154196, 0.20512820512820512, False, False), ('0_3096', 0, 3096, -0.014674097712154196, 0.20512820512820512, False, False), ('0 ...

# %%
f = open(f"data.csv", 'w', newline='', encoding='utf-8')
writer = csv.writer(f)
writer.writerow(['id', 'video_id', 'frame_id', 'sensor_z_score', 'sensor_min_max', 'predicted', 'ground_truth'])
writer.writerows(data_sorted)
f.close()
